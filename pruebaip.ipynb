# %% [markdown]
# <a href="https://colab.research.google.com/github/Areliortiz/SIMULACION2/blob/main/pruebaip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#subir archivo txt de mi computadora llamado -----

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c0a14c0-bced-4c36-8a5c-d0ec24ac34e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c0a14c0-bced-4c36-8a5c-d0ec24ac34e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from collections import Counter
#leer datos
with open('ip_server.txt', 'r') as file:
    datos=file.read().splitlines()
conteo_d=Counter(datos)
repetidos={dato:conteo for dato ,conteo in conteo_d.items() if conteo==2}
for dato,conteo in repetidos.items():
    print(f"{dato}")
# Out:
# 10.6.12.38
# 10.1.35.54
# 10.1.45.214
# 10.6.36.38
# 10.1.58.86
# 10.1.4.133
# 10.8.23.134
# 10.9.226.133
# 10.9.226.134
# 10.8.41.229
# 10.8.41.230
# 10.3.117.246
# 10.9.189.5
# 10.4.29.149
# 10.9.188.5
# 10.9.188.6
# 10.9.189.229
# 10.9.189.230
# 10.9.151.230
# 10.4.64.70
# 10.9.67.165
# 10.9.67.166
# 10.4.19.214
# 10.9.46.6
# 10.7.3.69
# 10.7.3.70
# 10.2.24.69
# 10.2.24.70
# 10.7.139.69
# 10.7.139.70
# 10.7.0.101
# 10.7.0.102
# 10.2.42.229
# 10.2.42.230
# 10.3.133.197
# 10.3.133.198
# 10.3.148.118
# 10.2.38.37
# 10.2.22.22
# 10.3.104.133
# 10.3.104.134
# 10.7.145.229
# 10.7.145.230
# 10.3.109.21
# 10.3.109.22
# 10.7.70.70
# 10.7.48.101
# 10.7.48.102
# 10.10.171.133
# 10.10.171.134
# 10.10.60.5
# 10.2.87.133
# 10.2.87.134
# 10.11.22.75
# 10.11.22.76
# 10.11.30.75
# 10.11.30.76
# 10.11.27.172
